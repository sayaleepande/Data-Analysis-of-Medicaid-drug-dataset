# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# for question 5
from io import StringIO

# %%
# Loading data
df_mdata = pd.read_csv("C:\\Users\\Sayal\\OneDrive\\Desktop\\6600_NU\\Assignment 1\\Medicaid_Spending_By_Drug_Data.csv")

# %%
# inspecting dataframe
df_mdata
# Out:
#                 Brnd_Name                       Gnrc_Name  Tot_Mftr  \
# 0      8hr Arthritis Pain                   Acetaminophen         1
# 1      8hr Arthritis Pain                   Acetaminophen         1
# 2                   A & D                Vitamins A And D         1
# 3                   A & D                Vitamins A And D         1
# 4                 A And D  Vits A And D/White Pet/Lanolin         1
# ...                   ...                             ...       ...
# 16141               Zyvox                       Linezolid         1
# 16142               Zyvox        Linezolid In Dextrose 5%         3
# 16143               Zyvox        Linezolid In Dextrose 5%         1
# 16144               Zyvox        Linezolid In Dextrose 5%         1
# 16145               Zyvox        Linezolid In Dextrose 5%         1
#
#              Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0              Overall              NaN                NaN            NaN
# ...

# %%
df_mdata.head
# Out:
# <bound method NDFrame.head of                 Brnd_Name                       Gnrc_Name  Tot_Mftr  \
# 0      8hr Arthritis Pain                   Acetaminophen         1
# 1      8hr Arthritis Pain                   Acetaminophen         1
# 2                   A & D                Vitamins A And D         1
# 3                   A & D                Vitamins A And D         1
# 4                 A And D  Vits A And D/White Pet/Lanolin         1
# ...                   ...                             ...       ...
# 16141               Zyvox                       Linezolid         1
# 16142               Zyvox        Linezolid In Dextrose 5%         3
# 16143               Zyvox        Linezolid In Dextrose 5%         1
# 16144               Zyvox        Linezolid In Dextrose 5%         1
# 16145               Zyvox        Linezolid In Dextrose 5%         1
#
#              Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# ...

# %%
# selecting top 10 rows
df_mdata.head(10)
# Out:
#              Brnd_Name                       Gnrc_Name  Tot_Mftr  \
# 0   8hr Arthritis Pain                   Acetaminophen         1
# 1   8hr Arthritis Pain                   Acetaminophen         1
# 2                A & D                Vitamins A And D         1
# 3                A & D                Vitamins A And D         1
# 4              A And D  Vits A And D/White Pet/Lanolin         1
# 5              A And D  Vits A And D/White Pet/Lanolin         1
# 6  A And D Diaper Rash  Dimethic/Zinc Ox/Vits A,D/Aloe         1
# 7  A And D Diaper Rash  Dimethic/Zinc Ox/Vits A,D/Aloe         1
# 8          A-Hydrocort    Hydrocortisone Sod Succinate         1
# 9          A-Hydrocort    Hydrocortisone Sod Succinate         1
#
#          Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0          Overall              NaN                NaN            NaN
# 1            Topco              NaN                NaN            NaN
# ...

# %%
# selecting bottom rows
df_mdata.tail(10)
# Out:
#       Brnd_Name                 Gnrc_Name  Tot_Mftr         Mftr_Name  \
# 16136  Zyprexa*                Olanzapine         1  Eli Lilly & Co.*
# 16137    Zytiga       Abiraterone Acetate         2           Overall
# 16138    Zytiga       Abiraterone Acetate         1    Janssen Pharm.
# 16139    Zytiga       Abiraterone Acetate         1   Janssen Biotech
# 16140     Zyvox                 Linezolid         1           Overall
# 16141     Zyvox                 Linezolid         1   Pharmaci/Pfizer
# 16142     Zyvox  Linezolid In Dextrose 5%         3           Overall
# 16143     Zyvox  Linezolid In Dextrose 5%         1   Pharmaci/Pfizer
# 16144     Zyvox  Linezolid In Dextrose 5%         1   Phar-Prep/Pfize
# 16145     Zyvox  Linezolid In Dextrose 5%         1   Phar-Nov/Pfizer
#
#        Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 16136       8240818.50          432253.20        12535.0
# 16137      49115337.85          601210.00         5651.0
# ...

# %%
# Inspecting dimensions: retrieveing the number of rows and columns 
df_mdata.shape
# Out:
# (16146, 36)

# %%
# Checking all column names
print(df_mdata.columns.tolist())
# Out:
# ['Brnd_Name', 'Gnrc_Name', 'Tot_Mftr', 'Mftr_Name', 'Tot_Spndng_2017', 'Tot_Dsg_Unts_2017', 'Tot_Clms_2017', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2017', 'Avg_Spnd_Per_Clm_2017', 'Outlier_Flag_2017', 'Tot_Spndng_2018', 'Tot_Dsg_Unts_2018', 'Tot_Clms_2018', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2018', 'Avg_Spnd_Per_Clm_2018', 'Outlier_Flag_2018', 'Tot_Spndng_2019', 'Tot_Dsg_Unts_2019', 'Tot_Clms_2019', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2019', 'Avg_Spnd_Per_Clm_2019', 'Outlier_Flag_2019', 'Tot_Spndng_2020', 'Tot_Dsg_Unts_2020', 'Tot_Clms_2020', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2020', 'Avg_Spnd_Per_Clm_2020', 'Outlier_Flag_2020', 'Tot_Spndng_2021', 'Tot_Dsg_Unts_2021', 'Tot_Clms_2021', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2021', 'Avg_Spnd_Per_Clm_2021', 'Outlier_Flag_2021', 'Chg_Avg_Spnd_Per_Dsg_Unt_20_21', 'CAGR_Avg_Spnd_Per_Dsg_Unt_17_21']

# %%
list(df_mdata)
# Out:
# ['Brnd_Name',
#  'Gnrc_Name',
#  'Tot_Mftr',
#  'Mftr_Name',
#  'Tot_Spndng_2017',
#  'Tot_Dsg_Unts_2017',
#  'Tot_Clms_2017',
#  'Avg_Spnd_Per_Dsg_Unt_Wghtd_2017',
#  'Avg_Spnd_Per_Clm_2017',
#  'Outlier_Flag_2017',
#  'Tot_Spndng_2018',
#  'Tot_Dsg_Unts_2018',
#  'Tot_Clms_2018',
#  'Avg_Spnd_Per_Dsg_Unt_Wghtd_2018',
#  'Avg_Spnd_Per_Clm_2018',
#  'Outlier_Flag_2018',
#  'Tot_Spndng_2019',
#  'Tot_Dsg_Unts_2019',
#  'Tot_Clms_2019',
#  'Avg_Spnd_Per_Dsg_Unt_Wghtd_2019',
#  'Avg_Spnd_Per_Clm_2019',
#  'Outlier_Flag_2019',
#  'Tot_Spndng_2020',
#  'Tot_Dsg_Unts_2020',
#  'Tot_Clms_2020',
#  'Avg_Spnd_Per_Dsg_Unt_Wghtd_2020',
#  'Avg_Spnd_Per_Clm_2020',
#  'Outlier_Flag_2020',
#  'Tot_Spndng_2021',
#  'Tot_Dsg_Unts_2021',
#  'Tot_Clms_2021',
#  'Avg_Spnd_Per_Dsg_Unt_Wghtd_2021',
#  'Avg_Spnd_Per_Clm_2021',
#  'Outlier_Flag_2021',
#  'Chg_Avg_Spnd_Per_Dsg_Unt_20_21',
#  'CAGR_Avg_Spnd_Per_Dsg_Unt_17_21']

# %%
df_mdata.columns
# Out:
# Index(['Brnd_Name', 'Gnrc_Name', 'Tot_Mftr', 'Mftr_Name', 'Tot_Spndng_2017',
#        'Tot_Dsg_Unts_2017', 'Tot_Clms_2017', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2017',
#        'Avg_Spnd_Per_Clm_2017', 'Outlier_Flag_2017', 'Tot_Spndng_2018',
#        'Tot_Dsg_Unts_2018', 'Tot_Clms_2018', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2018',
#        'Avg_Spnd_Per_Clm_2018', 'Outlier_Flag_2018', 'Tot_Spndng_2019',
#        'Tot_Dsg_Unts_2019', 'Tot_Clms_2019', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2019',
#        'Avg_Spnd_Per_Clm_2019', 'Outlier_Flag_2019', 'Tot_Spndng_2020',
#        'Tot_Dsg_Unts_2020', 'Tot_Clms_2020', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2020',
#        'Avg_Spnd_Per_Clm_2020', 'Outlier_Flag_2020', 'Tot_Spndng_2021',
#        'Tot_Dsg_Unts_2021', 'Tot_Clms_2021', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2021',
#        'Avg_Spnd_Per_Clm_2021', 'Outlier_Flag_2021',
#        'Chg_Avg_Spnd_Per_Dsg_Unt_20_21', 'CAGR_Avg_Spnd_Per_Dsg_Unt_17_21'],
#       dtype='object')

# %%
# Checking datatypes for all the columns
column_datatypes = df_mdata.dtypes
print(column_datatypes)
# Out:
# Brnd_Name                           object
# Gnrc_Name                           object
# Tot_Mftr                             int64
# Mftr_Name                           object
# Tot_Spndng_2017                    float64
# Tot_Dsg_Unts_2017                  float64
# Tot_Clms_2017                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    float64
# Avg_Spnd_Per_Clm_2017              float64
# Outlier_Flag_2017                  float64
# Tot_Spndng_2018                    float64
# Tot_Dsg_Unts_2018                  float64
# Tot_Clms_2018                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    float64
# Avg_Spnd_Per_Clm_2018              float64
# Outlier_Flag_2018                  float64
# Tot_Spndng_2019                    float64
# Tot_Dsg_Unts_2019                  float64
# Tot_Clms_2019                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    float64
# Avg_Spnd_Per_Clm_2019              float64
# Outlier_Flag_2019                  float64
# ...

# %%
# below is the summary of the dataset
df_mdata.describe()
# Out:
#            Tot_Mftr  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# count  16146.000000     1.113600e+04       1.113600e+04   1.113600e+04
# mean       1.461910     1.190001e+07       7.850797e+06   1.232592e+05
# std        2.289365     5.800085e+07       5.595186e+07   5.952454e+05
# min        1.000000     0.000000e+00       8.400000e-02   1.100000e+01
# 25%        1.000000     6.250336e+04       1.370190e+04   6.060000e+02
# 50%        1.000000     5.597136e+05       1.537005e+05   4.382500e+03
# 75%        1.000000     3.503468e+06       1.586952e+06   3.574625e+04
# max       44.000000     1.298196e+09       2.165630e+09   1.508415e+07
#
#        Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# count                     11136.000000           11136.000000
# mean                        135.265898            1014.855221
# std                        1067.442712            4626.057958
# min                           0.000000               0.000000
# ...

# %%
# checking for missing 
df_mdata.isnull()
# Out:
#        Brnd_Name  Gnrc_Name  Tot_Mftr  Mftr_Name  Tot_Spndng_2017  \
# 0          False      False     False      False             True
# 1          False      False     False      False             True
# 2          False      False     False      False             True
# 3          False      False     False      False             True
# 4          False      False     False      False            False
# ...          ...        ...       ...        ...              ...
# 16141      False      False     False      False            False
# 16142      False      False     False      False            False
# 16143      False      False     False      False            False
# 16144      False      False     False      False            False
# 16145      False      False     False      False            False
#
#        Tot_Dsg_Unts_2017  Tot_Clms_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  \
# 0                   True           True                             True
# ...

# %%
# Counting the number of missing values for all the columns
df_mdata.isnull().sum()
# Out:
# Brnd_Name                             0
# Gnrc_Name                             0
# Tot_Mftr                              0
# Mftr_Name                             0
# Tot_Spndng_2017                    5010
# Tot_Dsg_Unts_2017                  5010
# Tot_Clms_2017                      5010
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    5010
# Avg_Spnd_Per_Clm_2017              5010
# Outlier_Flag_2017                  5010
# Tot_Spndng_2018                    3851
# Tot_Dsg_Unts_2018                  3851
# Tot_Clms_2018                      3851
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    3851
# Avg_Spnd_Per_Clm_2018              3851
# Outlier_Flag_2018                  3851
# Tot_Spndng_2019                    2615
# Tot_Dsg_Unts_2019                  2615
# Tot_Clms_2019                      2615
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    2615
# Avg_Spnd_Per_Clm_2019              2615
# Outlier_Flag_2019                  2615
# Tot_Spndng_2020                    1447
# ...

# %%
# Getting the total number of elements 
tot_elements = np.product(df_mdata.shape)
# Counting the number of missing values
no_missing_values = df_mdata.isnull().sum().sum()
# Calculating the percentage of missing values
missing_values_percentage = (no_missing_values / tot_elements) * 100

df_mdata
# Out:
#                 Brnd_Name                       Gnrc_Name  Tot_Mftr  \
# 0      8hr Arthritis Pain                   Acetaminophen         1
# 1      8hr Arthritis Pain                   Acetaminophen         1
# 2                   A & D                Vitamins A And D         1
# 3                   A & D                Vitamins A And D         1
# 4                 A And D  Vits A And D/White Pet/Lanolin         1
# ...                   ...                             ...       ...
# 16141               Zyvox                       Linezolid         1
# 16142               Zyvox        Linezolid In Dextrose 5%         3
# 16143               Zyvox        Linezolid In Dextrose 5%         1
# 16144               Zyvox        Linezolid In Dextrose 5%         1
# 16145               Zyvox        Linezolid In Dextrose 5%         1
#
#              Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0              Overall     1.190001e+07       7.850797e+06  123259.199892
# ...

# %%
# Filling missing values with 0 


df_mdata['Tot_Spndng_2017'] = df_mdata['Tot_Spndng_2017'].fillna(0)
df_mdata['Tot_Dsg_Unts_2017'] = df_mdata['Tot_Dsg_Unts_2017'].fillna(0)
df_mdata['Tot_Clms_2017'] = df_mdata['Tot_Clms_2017'].fillna(0)
df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2017'] = df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2017'].fillna(0)
df_mdata['Avg_Spnd_Per_Clm_2017'] = df_mdata['Avg_Spnd_Per_Clm_2017'].fillna(0)

# Filling missing values for the year of 2018 with mean values
df_mdata['Tot_Spndng_2018'] = df_mdata['Tot_Spndng_2018'].fillna(0)
df_mdata['Tot_Dsg_Unts_2018'] = df_mdata['Tot_Dsg_Unts_2018'].fillna(0)
df_mdata['Tot_Clms_2018'] = df_mdata['Tot_Clms_2018'].fillna(0)
df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2018'] = df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2018'].fillna(0)
df_mdata['Avg_Spnd_Per_Clm_2018'] = df_mdata['Avg_Spnd_Per_Clm_2018'].fillna(0)

# Filling missing values for the year of 2019 with mean values
df_mdata['Tot_Spndng_2019'] = df_mdata['Tot_Spndng_2019'].fillna(0)
df_mdata['Tot_Dsg_Unts_2019'] = df_mdata['Tot_Dsg_Unts_2019'].fillna(0)
df_mdata['Tot_Clms_2019'] = df_mdata['Tot_Clms_2019'].fillna(0)
df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2019'] = df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2019'].fillna(0)
df_mdata['Avg_Spnd_Per_Clm_2019'] = df_mdata['Avg_Spnd_Per_Clm_2019'].fillna(0)

# Filling missing values for the year of 2020 with mean values
df_mdata['Tot_Spndng_2020'] = df_mdata['Tot_Spndng_2020'].fillna(0)
df_mdata['Tot_Dsg_Unts_2020'] = df_mdata['Tot_Dsg_Unts_2020'].fillna(0)
df_mdata['Tot_Clms_2020'] = df_mdata['Tot_Clms_2020'].fillna(0)
df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2020'] = df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2020'].fillna(0)
df_mdata['Avg_Spnd_Per_Clm_2020'] = df_mdata['Avg_Spnd_Per_Clm_2020'].fillna(0)


df_mdata.isnull().sum()

#df_mdata
# Out:
# Brnd_Name                          0
# Gnrc_Name                          0
# Tot_Mftr                           0
# Mftr_Name                          0
# Tot_Spndng_2017                    0
# Tot_Dsg_Unts_2017                  0
# Tot_Clms_2017                      0
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    0
# Avg_Spnd_Per_Clm_2017              0
# Outlier_Flag_2017                  0
# Tot_Spndng_2018                    0
# Tot_Dsg_Unts_2018                  0
# Tot_Clms_2018                      0
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    0
# Avg_Spnd_Per_Clm_2018              0
# Outlier_Flag_2018                  0
# Tot_Spndng_2019                    0
# Tot_Dsg_Unts_2019                  0
# Tot_Clms_2019                      0
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    0
# Avg_Spnd_Per_Clm_2019              0
# Outlier_Flag_2019                  0
# Tot_Spndng_2020                    0
# Tot_Dsg_Unts_2020                  0
# Tot_Clms_2020                      0
# ...

# %%
# Outlier flag: filling missing values with zero

df_mdata['Outlier_Flag_2017'] = df_mdata['Outlier_Flag_2017'].fillna(0)
df_mdata['Outlier_Flag_2018'] = df_mdata['Outlier_Flag_2017'].fillna(0)
df_mdata['Outlier_Flag_2019'] = df_mdata['Outlier_Flag_2017'].fillna(0)
df_mdata['Outlier_Flag_2020'] = df_mdata['Outlier_Flag_2017'].fillna(0)

# %%
df_mdata['Chg_Avg_Spnd_Per_Dsg_Unt_20_21'] = df_mdata['Chg_Avg_Spnd_Per_Dsg_Unt_20_21'].fillna(method='ffill')
df_mdata.isnull().sum()

df_mdata['CAGR_Avg_Spnd_Per_Dsg_Unt_17_21'] = df_mdata['Chg_Avg_Spnd_Per_Dsg_Unt_20_21'].fillna(method='ffill')
df_mdata.isnull().sum()
# Out:
# Brnd_Name                             0
# Gnrc_Name                             0
# Tot_Mftr                              0
# Mftr_Name                             0
# Tot_Spndng_2017                    5010
# Tot_Dsg_Unts_2017                  5010
# Tot_Clms_2017                      5010
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    5010
# Avg_Spnd_Per_Clm_2017              5010
# Outlier_Flag_2017                     0
# Tot_Spndng_2018                    3851
# Tot_Dsg_Unts_2018                  3851
# Tot_Clms_2018                      3851
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    3851
# Avg_Spnd_Per_Clm_2018              3851
# Outlier_Flag_2018                     0
# Tot_Spndng_2019                    2615
# Tot_Dsg_Unts_2019                  2615
# Tot_Clms_2019                      2615
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    2615
# Avg_Spnd_Per_Clm_2019              2615
# Outlier_Flag_2019                     0
# Tot_Spndng_2020                    1447
# ...

# %%
display(df_mdata.dtypes)
# Out:
# Brnd_Name                           object
# Gnrc_Name                           object
# Tot_Mftr                             int64
# Mftr_Name                           object
# Tot_Spndng_2017                    float64
# Tot_Dsg_Unts_2017                  float64
# Tot_Clms_2017                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    float64
# Avg_Spnd_Per_Clm_2017              float64
# Outlier_Flag_2017                  float64
# Tot_Spndng_2018                    float64
# Tot_Dsg_Unts_2018                  float64
# Tot_Clms_2018                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    float64
# Avg_Spnd_Per_Clm_2018              float64
# Outlier_Flag_2018                  float64
# Tot_Spndng_2019                    float64
# Tot_Dsg_Unts_2019                  float64
# Tot_Clms_2019                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    float64
# Avg_Spnd_Per_Clm_2019              float64
# Outlier_Flag_2019                  float64
# ...

# %%
#data cleaning

print(df_mdata.dtypes)
df_mdata['Tot_Clms_2017'] = df_mdata['Tot_Clms_2017'].apply(np.int64)
df_mdata['Tot_Clms_2018'] = df_mdata['Tot_Clms_2018'].apply(np.int64)
df_mdata['Tot_Clms_2019'] = df_mdata['Tot_Clms_2019'].apply(np.int64)
df_mdata['Tot_Clms_2020'] = df_mdata['Tot_Clms_2020'].apply(np.int64)
# Out:
# Brnd_Name                           object
# Gnrc_Name                           object
# Tot_Mftr                             int64
# Mftr_Name                           object
# Tot_Spndng_2017                    float64
# Tot_Dsg_Unts_2017                  float64
# Tot_Clms_2017                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    float64
# Avg_Spnd_Per_Clm_2017              float64
# Outlier_Flag_2017                  float64
# Tot_Spndng_2018                    float64
# Tot_Dsg_Unts_2018                  float64
# Tot_Clms_2018                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    float64
# Avg_Spnd_Per_Clm_2018              float64
# Outlier_Flag_2018                  float64
# Tot_Spndng_2019                    float64
# Tot_Dsg_Unts_2019                  float64
# Tot_Clms_2019                      float64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    float64
# Avg_Spnd_Per_Clm_2019              float64
# Outlier_Flag_2019                  float64
# ...

# %%
# Outlier flag: Changing data type of Outlier flag to int
                                                                                                              
df_mdata['Outlier_Flag_2017'] = df_mdata['Outlier_Flag_2017'].astype(int)
df_mdata['Outlier_Flag_2018'] = df_mdata['Outlier_Flag_2018'].astype(int)
df_mdata['Outlier_Flag_2019'] = df_mdata['Outlier_Flag_2019'].astype(int)
df_mdata['Outlier_Flag_2020'] = df_mdata['Outlier_Flag_2020'].astype(int)

display(df_mdata.dtypes)
# Out:
# Brnd_Name                           object
# Gnrc_Name                           object
# Tot_Mftr                             int64
# Mftr_Name                           object
# Tot_Spndng_2017                    float64
# Tot_Dsg_Unts_2017                  float64
# Tot_Clms_2017                        int64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    float64
# Avg_Spnd_Per_Clm_2017              float64
# Outlier_Flag_2017                    int32
# Tot_Spndng_2018                    float64
# Tot_Dsg_Unts_2018                  float64
# Tot_Clms_2018                        int64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    float64
# Avg_Spnd_Per_Clm_2018              float64
# Outlier_Flag_2018                    int32
# Tot_Spndng_2019                    float64
# Tot_Dsg_Unts_2019                  float64
# Tot_Clms_2019                        int64
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    float64
# Avg_Spnd_Per_Clm_2019              float64
# Outlier_Flag_2019                    int32
# ...

# %%
#Filling missing values of Outlier flag with zero

df_mdata['Outlier_Flag_2017'] = df_mdata['Outlier_Flag_2017'].fillna(0)
df_mdata['Outlier_Flag_2018'] = df_mdata['Outlier_Flag_2017'].fillna(0)
df_mdata['Outlier_Flag_2019'] = df_mdata['Outlier_Flag_2017'].fillna(0)
df_mdata['Outlier_Flag_2020'] = df_mdata['Outlier_Flag_2017'].fillna(0)

df_mdata.isnull().sum()
# Out:
# Brnd_Name                          0
# Gnrc_Name                          0
# Tot_Mftr                           0
# Mftr_Name                          0
# Tot_Spndng_2017                    0
# Tot_Dsg_Unts_2017                  0
# Tot_Clms_2017                      0
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    0
# Avg_Spnd_Per_Clm_2017              0
# Outlier_Flag_2017                  0
# Tot_Spndng_2018                    0
# Tot_Dsg_Unts_2018                  0
# Tot_Clms_2018                      0
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    0
# Avg_Spnd_Per_Clm_2018              0
# Outlier_Flag_2018                  0
# Tot_Spndng_2019                    0
# Tot_Dsg_Unts_2019                  0
# Tot_Clms_2019                      0
# Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    0
# Avg_Spnd_Per_Clm_2019              0
# Outlier_Flag_2019                  0
# Tot_Spndng_2020                    0
# Tot_Dsg_Unts_2020                  0
# Tot_Clms_2020                      0
# ...

# %%
# checking for duplicate values
duplicate_values = df_mdata.duplicated()
print(duplicate_values)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16141    False
# 16142    False
# 16143    False
# 16144    False
# 16145    False
# Length: 16146, dtype: bool

# %%
# Checking for any duplicate values
actual_file_path = "C:\\Users\\Sayal\\OneDrive\\Desktop\\6600_NU\\Assignment 1\\Medicaid_Spending_By_Drug_Data.csv"
df_mdata = pd.read_csv("C:\\Users\\Sayal\\OneDrive\\Desktop\\6600_NU\\Assignment 1\\Medicaid_Spending_By_Drug_Data.csv")
duplicate_rows_present = df_mdata.duplicated().any()
if duplicate_rows_present:
    print("Yes! The file contains duplicate values")
else:
    print("No! The file does not contain duplicate values")
# Out:
# No! The file does not contain duplicate values

# %%
# Checking for inconsistent and incomplete data 

#removing * from manufacturer column
df_mdata['Mftr_Name'] = df_mdata['Mftr_Name'].str.rstrip('*')
df_mdata['Mftr_Name']
# Out:
# 0                Overall
# 1                  Topco
# 2                Overall
# 3        Schering-Plough
# 4                Overall
#               ...
# 16141    Pharmaci/Pfizer
# 16142            Overall
# 16143    Pharmaci/Pfizer
# 16144    Phar-Prep/Pfize
# 16145    Phar-Nov/Pfizer
# Name: Mftr_Name, Length: 16146, dtype: object

# %%
# Question 2: Identify the brand with the highest total spending in 2019

index_of_highest_total_spending = df_mdata['Tot_Spndng_2019'].idxmax()
brand_name_highest_total_spending_2019 = df_mdata.loc[index_of_highest_total_spending, 'Brnd_Name']
print(brand_name_highest_total_spending_2019)
index_of_highest_total_spending = df_mdata['Tot_Spndng_2019'].idxmax()
Highest_total_spending_2019 = df_mdata.loc[index_of_highest_total_spending, 'Tot_Spndng_2019']
print(Highest_total_spending_2019)
# Out:
# Latuda
# 1346188758.6

# %%
# Question 3: Generate the table showing the top 5 manufacturers with the hihgest total spending in 2018. Plot a histogram using Python

mftr = df_mdata.groupby(['Mftr_Name'])
total_spending_mftr_2018 = mftr['Tot_Spndng_2018'].sum()
mftr_sort = total_spending_mftr_2018.sort_values(ascending=False)
top_five_mftr_hihest_tot_spending_2018 = mftr_sort.head(5)

# Bar chart
plt.figure(figsize=(10,6))
plt.bar(top_five_mftr_hihest_tot_spending_2018.index,top_five_mftr_hihest_tot_spending_2018.values, color='skyblue')
plt.xlabel('Manufacturer')
plt.ylabel('Total Spending in 2018')
plt.title('Total Spending by Manufacturer in year 2018')
plt.show()

# creating a dataframe to generate a table
table = pd.DataFrame({'Manufacturer':top_five_mftr_hihest_tot_spending_2018.index, 'Total Spending in 2018':top_five_mftr_hihest_tot_spending_2018.values})
print("Below is the table showing top 5 manufacturers with the highest total spending in the year 2018")
table
# Out:
# Below is the table showing top 5 manufacturers with the highest total spending in the year 2018
#       Manufacturer  Total Spending in 2018
# 0          Overall            6.612381e+10
# 1  Gilead Sciences            4.041785e+09
# 2    Abbvie US LLC            3.441056e+09
# 3  Glaxosmithkline            2.327969e+09
# 4  Eli Lilly & Co.            2.313548e+09

# %%
# Question 4: List the generic names with the highest average spending per claim in 2017.

names_generic = df_mdata.groupby(['Gnrc_Name'])
tot_avg_spend_per_claim_2017 = names_generic['Avg_Spnd_Per_Clm_2017'].sum()
sorting_of_generic_names = tot_avg_spend_per_claim_2017.sort_values(ascending=False)
top_generic_names_highest_tot_avg_spend_per_claim_2017 = sorting_of_generic_names.head(5)

# creating a dataframe to generate a table
table = pd.DataFrame({'Generic Names':top_generic_names_highest_tot_avg_spend_per_claim_2017.index, 'Highest Average Spending Claim in 2017':top_generic_names_highest_tot_avg_spend_per_claim_2017.values})
print("Below is the table showing top generic names with the highest average spending per claim in 2017")
table
# Out:
# Below is the table showing top generic names with the highest average spending per claim in 2017
#                     Generic Names  Highest Average Spending Claim in 2017
# 0            Nusinersen Sodium/PF                           268609.739260
# 1  Coagulation Factor VIIA,Recomb                           201692.086640
# 2           C1 Esterase Inhibitor                           184313.731938
# 3  Antihemophil.FVIII,Full Length                           141039.561698
# 4       Antihemophilic Factor/VWF                           137687.955198

# %%
# Question 5: Create a table displaying the brands with the highest total claims in 2018


brand_name = df_mdata.groupby(['Brnd_Name'])
tot_claim_2018 = brand_name['Tot_Clms_2018'].sum()
sorting_of_brand_names = tot_claim_2018.sort_values(ascending=False)
top_brands_highest_tot_claim_2018 = sorting_of_brand_names.head(5)

# creating a dataframe to generate a table
table = pd.DataFrame({'Brand Names':top_brands_highest_tot_claim_2018.index, 'Highest Total CLaims in 2018':top_brands_highest_tot_claim_2018.values})
print("Below is the table showing top brands with highest total claims in 2018")
table
# Out:
# Below is the table showing top brands with highest total claims in 2018
#             Brand Names  Highest Total CLaims in 2018
# 0           Amoxicillin                    28170752.0
# 1            Gabapentin                    26688688.0
# 2             Ibuprofen                    25762050.0
# 3  Atorvastatin Calcium                    25615284.0
# 4            Lisinopril                    23698512.0

# %%
# Question 6: Identify the brand with the highest average spending per dosage unit in 2018 

index_of_highest_avg_spending_per_dosage_unit_2018 = df_mdata['Avg_Spnd_Per_Dsg_Unt_Wghtd_2018'].idxmax()
brand_name_highest_avg_spending_per_dosage_unit_2018 = df_mdata.loc[index_of_highest_avg_spending_per_dosage_unit_2018, 'Brnd_Name']
print(brand_name_highest_avg_spending_per_dosage_unit_2018)
# Out:
# Kymriah

# %%
# Question 7: Create a table listing the top 3 generic names with the highest total spending in 2019. Plot a histogram using Python.

names_generic = df_mdata.groupby(['Gnrc_Name'])
total_spending_2019 = names_generic['Tot_Spndng_2019'].sum()
sorting_of_generic_names = total_spending_2019.sort_values(ascending=False)
top_three_generic_names_highest_tot_spending_2019 = sorting_of_generic_names.head(3)

plt.figure(figsize=(10,6))

plt.bar(top_three_generic_names_highest_tot_spending_2019.index, top_three_generic_names_highest_tot_spending_2019.values, color='skyblue', edgecolor='black')
plt.xlabel('Generic Names')
plt.ylabel('Total SPending 2019')
plt.title('Top 3 generic names with the highest total spending in 2019')
plt.show()

# creating a dataframe to generate a table
table = pd.DataFrame({'Generic Names':top_three_generic_names_highest_tot_spending_2019.index, 'Highest Total Spending in 2019':top_three_generic_names_highest_tot_spending_2019.values})
print("Below is the table showing top 3 generic names with the highest total spending in the year 2019")
table
# Out:
# Below is the table showing top 3 generic names with the highest total spending in the year 2019
#                     Generic Names  Highest Total Spending in 2019
# 0                      Adalimumab                    4.690149e+09
# 1  Insulin Glargine,Hum.Rec.Anlog                    3.155721e+09
# 2                  Lurasidone HCl                    2.692378e+09

# %%
# Question 8: Build a table displaying the brands with the highest average spending per claim in 2019.

brand_names = df_mdata.groupby(['Brnd_Name'])
total_avg_spending_per_claim_2019 = brand_names['Avg_Spnd_Per_Clm_2019'].sum()
sorting_of_brand_names = total_avg_spending_per_claim_2019.sort_values(ascending=False)
top_brand_names_highest_avg_spending_per_claim_2019 = sorting_of_brand_names.head(10)

# creating a dataframe to generate a table
table = pd.DataFrame({'Brand Names':top_brand_names_highest_avg_spending_per_claim_2019.index, 'Highest Average spending Per Claim 2019':top_brand_names_highest_avg_spending_per_claim_2019.values})
print("Below is the table showing top brand names with the highest average spending per claim 2019")
table
# Out:
# Below is the table showing top brand names with the highest average spending per claim 2019
#     Brand Names  Highest Average spending Per Claim 2019
# 0     Zolgensma                             3.435723e+06
# 1       Revcovi                             3.743077e+05
# 2      Gamifant                             3.584478e+05
# 3       Cablivi                             2.803050e+05
# 4      Spinraza                             2.387944e+05
# 5  Novoseven RT                             1.780818e+05
# 6      Mepsevii                             1.618121e+05
# 7       Myalept                             1.589701e+05
# 8      Ruconest                             1.459186e+05
# 9      Feiba NF                             1.354486e+05

# %%
# Question 9: Generate a table showing the top 5 mnufacturers with the highest total spending across all years. Plot a histogram using Python

df_new = df_mdata[['Mftr_Name', 'Tot_Spndng_2017', 'Tot_Spndng_2018','Tot_Spndng_2019','Tot_Spndng_2020','Tot_Spndng_2021']]

df_new = df_new.assign(total = ((df_new['Tot_Spndng_2017'] + df_new['Tot_Spndng_2018'] + df_new['Tot_Spndng_2019'] + df_new['Tot_Spndng_2020'] + df_new['Tot_Spndng_2021'])))

top_five_manufacturers_highest_tot_spending = df_new.groupby(['Mftr_Name'])['total'].sum().nlargest(5)

#plotting chart
plt.figure(figsize=(10,6))
plt.bar(top_five_manufacturers_highest_tot_spending.index, top_five_manufacturers_highest_tot_spending.values, color='skyblue', edgecolor='black')
plt.xlabel('Mftr_Name')
plt.ylabel('total')
plt.title('Top 5 manufacturers with the highest total spending across all years')
plt.show()

# creating a dataframe to generate a table
table = pd.DataFrame({'Manufacturers':top_five_manufacturers_highest_tot_spending.index, 'Highest Total Spending':top_five_manufacturers_highest_tot_spending.values})
print("Below is the table showing top 5 manufacturers with highest total spending across all years")
table
# Out:
# Below is the table showing top 5 manufacturers with highest total spending across all years
#      Manufacturers  Highest Total Spending
# 0          Overall            3.675242e+11
# 1  Gilead Sciences            2.296129e+10
# 2    Abbvie US LLC            1.947680e+10
# 3  Eli Lilly & Co.            1.323722e+10
# 4     Novo Nordisk            1.287389e+10

# %%
# Question 10: (Including missing values that I have filled with zero) Identify the generic name with the highest percentage increase in total spending from 2017 to 2019.

# 1st table is for value including 0
df_new = df_mdata[['Gnrc_Name', 'Tot_Spndng_2017','Tot_Spndng_2019']]

df_new = df_new.assign(percentage_increase = ((df_new['Tot_Spndng_2019'] - df_new['Tot_Spndng_2017']) / df_new['Tot_Spndng_2017']) * 100)

df_new.nlargest(1, 'percentage_increase')
# Out:
#        Gnrc_Name  Tot_Spndng_2017  Tot_Spndng_2019  percentage_increase
# 0  Acetaminophen              0.0           733.42                  inf

# %%
# Question 10: (Not Including missing values that I have filled with zero)
df_new = df_mdata[['Gnrc_Name', 'Tot_Spndng_2017','Tot_Spndng_2019']]

df_new = df_new.loc[(df_new != 0).all(axis=1), :].assign(percentage_increase = ((df_new['Tot_Spndng_2019'] - df_new['Tot_Spndng_2017']) / df_new['Tot_Spndng_2017']) * 100)

df_new.nlargest(1, 'percentage_increase')
# Out:
#                       Gnrc_Name  Tot_Spndng_2017  Tot_Spndng_2019  \
# 13781  Succinylcholine Chloride              3.2        867264.61
#
#        percentage_increase
# 13781         2.710192e+07

# %%
#Question 11: Create a table displaying the top 3 brands with the highest average spending per dosage unit weigheted in 2018. Plot a histogram using Python.

brand_name = df_mdata.groupby(['Brnd_Name'])
avg_spend_per_dosage_unit_2018 = brand_name['Avg_Spnd_Per_Dsg_Unt_Wghtd_2018'].sum()
sorting_of_brand_names = avg_spend_per_dosage_unit_2018.sort_values(ascending=False)
top_three_brands_highest_avg_spending_per_dosage_2018 = sorting_of_brand_names.head(3)



plt.figure(figsize=(10,6))

plt.bar(top_three_brands_highest_avg_spending_per_dosage_2018.index, top_three_brands_highest_avg_spending_per_dosage_2018.values, color='skyblue', edgecolor='black')
plt.xlabel('Top 3 Brands')
plt.ylabel('Highest Average Spending Per Dosage')
plt.title('Top 3 brands with the highest average spending per dosage unit weigheted in 2018')
plt.show()

# creating a dataframe to generate a table
table = pd.DataFrame({'Brand Names':top_three_brands_highest_avg_spending_per_dosage_2018.index, 'Highest Average Spending Per Dosage Unit 2018':top_three_brands_highest_avg_spending_per_dosage_2018.values})
table
# Out:
#     Brand Names  Highest Average Spending Per Dosage Unit 2018
# 0       Kymriah                                  286905.171580
# 1         Eylea                                   66715.142344
# 2  Supprelin La                                   60573.203590

# %%
# Question 12: Generate a table showing the percentage change in total claims from 2017 to 2019 for each manufacturer.

df_percent_change_claim = df_mdata[['Mftr_Name', 'Tot_Clms_2017','Tot_Clms_2019']]

df_percent_change_claim = df_percent_change_claim.loc[(df_percent_change_claim != 0).all(axis=1), :].assign(percentage_change = ((df_percent_change_claim['Tot_Clms_2019'] - df_percent_change_claim['Tot_Clms_2017']) / df_percent_change_claim['Tot_Clms_2017']) * 100)

df_percent_change_claim
# Out:
#              Mftr_Name  Tot_Clms_2017  Tot_Clms_2019  percentage_change
# 4              Overall           47.0           17.0         -63.829787
# 5      Bayer Healthcar           47.0           17.0         -63.829787
# 8              Overall           67.0           34.0         -49.253731
# 9       Hospira/Pfizer           67.0           34.0         -49.253731
# 10             Overall          453.0          187.0         -58.719647
# ...                ...            ...            ...                ...
# 16141  Pharmaci/Pfizer          314.0           54.0         -82.802548
# 16142          Overall         1308.0          690.0         -47.247706
# 16143  Pharmaci/Pfizer          987.0          362.0         -63.323202
# 16144  Phar-Prep/Pfize          169.0          190.0          12.426036
# 16145  Phar-Nov/Pfizer          152.0          138.0          -9.210526
#
# [11029 rows x 4 columns]

# %%
# Question 13: List the top 5 rows with the highest total spending in 2019. Plot a histogram using Python.


df_top_five_rows_highest_tot_spending_2019 = df_mdata.sort_values('Tot_Spndng_2019',ascending=False).head(5)

df_new = df_top_five_rows_highest_tot_spending_2019[['Mftr_Name', 'Tot_Spndng_2019']]

df_new.plot.bar(x='Mftr_Name', y='Tot_Spndng_2019', rot=0)

df_top_five_rows_highest_tot_spending_2019
# Out:
#             Brnd_Name                       Gnrc_Name  Tot_Mftr  \
# 8172           Latuda                  Lurasidone HCl         1
# 8173           Latuda                  Lurasidone HCl         1
# 1647         Biktarvy  Bictegrav/Emtricit/Tenofov Ala         1
# 1648         Biktarvy  Bictegrav/Emtricit/Tenofov Ala         1
# 7543  Invega Sustenna          Paliperidone Palmitate         1
#
#             Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 8172          Overall     1.105327e+09       2.961813e+07       970531.0
# 8173  Sunovion Pharma     1.105327e+09       2.961813e+07       970531.0
# 1647          Overall     0.000000e+00       0.000000e+00            0.0
# 1648  Gilead Sciences     0.000000e+00       0.000000e+00            0.0
# 7543   Janssen Pharm.     7.545156e+08       4.926159e+05       407806.0
#
#       Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 8172                        37.411275            1138.888885
# ...

# %%
# Question 14: Build a table listing the top 3 rows with the highest average spending per claim in 2018. Plot a histogram using Python

df_top_three_rows_highest_avg_spending_per_claim_2018 = df_mdata.sort_values('Avg_Spnd_Per_Clm_2018',ascending=False).head(3)

df_top_three_rows_highest_avg_spending_per_claim_2018.plot.bar(x='Mftr_Name', y='Avg_Spnd_Per_Clm_2018', rot=0)

df_top_three_rows_highest_avg_spending_per_claim_2018
# Out:
#       Brnd_Name             Gnrc_Name  Tot_Mftr    Mftr_Name  Tot_Spndng_2017  \
# 7974    Kymriah      Tisagenlecleucel         1     Novartis     0.000000e+00
# 7973    Kymriah      Tisagenlecleucel         1      Overall     0.000000e+00
# 13675  Spinraza  Nusinersen Sodium/PF         1  Biogen-Idec     1.318874e+08
#
#        Tot_Dsg_Unts_2017  Tot_Clms_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  \
# 7974               0.000            0.0                         0.000000
# 7973               0.000            0.0                         0.000000
# 13675           5718.499          982.0                     23063.286709
#
#        Avg_Spnd_Per_Clm_2017  Outlier_Flag_2017  ...  Avg_Spnd_Per_Clm_2020  \
# 7974                 0.00000                0.0  ...                0.00000
# 7973                 0.00000                0.0  ...                0.00000
# 13675           134304.86963                0.0  ...           118446.05743
#
# ...

# %%
# Question 15: Identify the manufacturer with the highest total spending in 2017, considering only brands with a positive trend in total claims from 2017 to 2018. 

df_new = df_mdata[['Mftr_Name', 'Brnd_Name', 'Tot_Clms_2017', 'Tot_Clms_2018']]

df_new1 = df_new.groupby(['Brnd_Name'])[['Tot_Clms_2017', 'Tot_Clms_2018']].sum()

df_new1 = df_new1.loc[df_new1['Tot_Clms_2018'] > df_new1['Tot_Clms_2017']]

df_top_spending = pd.merge(df_new1, df_mdata, on='Brnd_Name', how='inner')

df_top_spending.groupby(['Mftr_Name'])['Tot_Spndng_2017'].sum().nlargest(1)
# Out:
# Mftr_Name
# Overall    2.925735e+10
# Name: Tot_Spndng_2017, dtype: float64

# %%
# Question 16: Create a table displaying the top 3 brands with the highest percentage increase in average spending per claim from 2017 to 2019. Plot a histogram using Python.

#Filtering out column values where average spending is zero(missing data)
df_percent_increase_avg_spend_claim = df_mdata[['Brnd_Name', 'Avg_Spnd_Per_Clm_2017','Avg_Spnd_Per_Clm_2019']]

df_percent_increase_avg_spend_claim = df_percent_increase_avg_spend_claim.loc[(df_percent_increase_avg_spend_claim !=0).all(axis=1), :].assign(percentage_increase = ((df_percent_increase_avg_spend_claim['Avg_Spnd_Per_Clm_2019'] - df_percent_increase_avg_spend_claim['Avg_Spnd_Per_Clm_2017']) / df_percent_increase_avg_spend_claim['Avg_Spnd_Per_Clm_2017']) * 100)
df_percent_increase_avg_spend_claim = df_percent_increase_avg_spend_claim.nlargest(3, 'percentage_increase')
df_percent_increase_avg_spend_claim


df_percent_increase_avg_spend_claim.plot.bar(x='Brnd_Name', y='percentage_increase', rot=0)
df_percent_increase_avg_spend_claim
# Out:
#                       Brnd_Name  Avg_Spnd_Per_Clm_2017  Avg_Spnd_Per_Clm_2019  \
# 13781  Succinylcholine Chloride               0.037209             469.299031
# 12529         Protamine Sulfate               1.722110             704.011952
# 6897            Heparin Sodium*               8.354444            2322.270000
#
#        percentage_increase
# 13781         1.261141e+06
# 12529         4.078078e+04
# 6897          2.769682e+04

# %%
# Question 17: Identify the brand with the highest average spending per claim in 2019, considering only brands with a decreasing trend in total spending from 2018 to 2019

df_new = df_mdata[['Brnd_Name', 'Avg_Spnd_Per_Clm_2018', 'Avg_Spnd_Per_Clm_2019']]

df_new1 = df_new.groupby(['Brnd_Name'])[['Avg_Spnd_Per_Clm_2018', 'Avg_Spnd_Per_Clm_2019']].sum()

df_new1 = df_new1.loc[df_new1['Avg_Spnd_Per_Clm_2018'] > df_new1['Avg_Spnd_Per_Clm_2019']]

# Joined the full data with filtered brands 
df_top_spending = pd.merge(df_new1, df_mdata[['Brnd_Name', 'Avg_Spnd_Per_Clm_2019']], on='Brnd_Name', how='inner')

df_top_spending

df_top_spending.groupby(['Brnd_Name'])['Avg_Spnd_Per_Clm_2019_y'].sum().nlargest(1)
# Out:
# Brnd_Name
# Spinraza    238794.38158
# Name: Avg_Spnd_Per_Clm_2019_y, dtype: float64

# %%
# Question 18: Create a table displaying the top 5 manufacturers with the highest average spending per dosage unit in 2018, but exclude manufacturers with an oulier flag? Plot a histogram using Python


mftr_name_filter = df_mdata[['Mftr_Name', 'Outlier_Flag_2018', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2018']].loc[df_mdata['Outlier_Flag_2018'] != 1]

avg_spend_per_dosage_unit_2018 = mftr_name_filter.groupby(['Mftr_Name'])['Avg_Spnd_Per_Dsg_Unt_Wghtd_2018'].sum().sort_values(ascending=False).nlargest(5)


avg_spend_per_dosage_unit_2018.plot.bar(x='Mftr_Name', y='Avg_Spnd_Per_Dsg_Unt_Wghtd_2018', rot=0)

avg_spend_per_dosage_unit_2018
# Out:
# Mftr_Name
# Overall            796020.342851
# Novartis           183744.870830
# Genentech, Inc.     51340.074490
# Abbvie US LLC       43610.421109
# Biogen-Idec         40341.431553
# Name: Avg_Spnd_Per_Dsg_Unt_Wghtd_2018, dtype: float64

# %%
#Question 19: Find manufacturers that have names with an odd numbers of characters.
# Calculate the total spending for brands associated with these manufacturers in 2019 and list the top 3 manufacturers

mftr_characters = df_mdata[['Mftr_Name']]
odd_number_char_manufacturers = [x for i,x in enumerate(mftr_characters['Mftr_Name']) if len(x)%2!=0]

odd_number_char_manufacturers


df_new = df_mdata[['Mftr_Name','Tot_Spndng_2019']]

df_new = df_new[df_new['Mftr_Name'].isin(odd_number_char_manufacturers)]

df_new.groupby(['Mftr_Name'])['Tot_Spndng_2019'].sum().nlargest(3)
# Out:
# Mftr_Name
# Overall            7.207820e+10
# Gilead Sciences    4.401205e+09
# Abbvie US LLC      3.932866e+09
# Name: Tot_Spndng_2019, dtype: float64

# %%
# Question 20: Identify the manufacturer with the highest total spending across all brands in 2018. List the top 3 brands associated with this manufacturer

df_mftr_tot_spend_2018 = df_mdata[['Mftr_Name','Tot_Spndng_2018', 'Brnd_Name']]

tot_spend_2018 = df_mftr_tot_spend_2018.groupby(['Mftr_Name'])['Tot_Spndng_2018'].sum()

# Find out the manufacturer with highest total spending.
sorting_of_manufacturer = tot_spend_2018.sort_values(ascending=False).nlargest(1)

# Filter to only manufacturer with highest total spending.
top_mfg = df_mdata[['Mftr_Name','Tot_Spndng_2018', 'Brnd_Name']].loc[df_mdata['Mftr_Name'] == sorting_of_manufacturer.index[0]]

top_3_brands_associated_with_highest_spending_mftr = top_mfg.groupby(['Mftr_Name','Brnd_Name'])['Tot_Spndng_2018'].sum().nlargest(3)

top_3_brands_associated_with_highest_spending_mftr
# Out:
# Mftr_Name  Brnd_Name
# Overall    Humira Pen    1.394367e+09
#            Latuda        1.250847e+09
#            Mavyret       1.025846e+09
# Name: Tot_Spndng_2018, dtype: float64

# %%
# Question: 21 For each of the top 3 brands identified in Question 20, calculate the percentage increase in average spending per claim from 2018 to 2019

df_new = df_mdata[['Brnd_Name', 'Mftr_Name', 'Avg_Spnd_Per_Clm_2018','Avg_Spnd_Per_Clm_2019']]

df_new = df_new.loc[((df_new['Brnd_Name'] == top_3_brands_associated_with_highest_spending_mftr.index[0][1]) | (df_new['Brnd_Name'] == top_3_brands_associated_with_highest_spending_mftr.index[1][1]) | (df_new['Brnd_Name'] == top_3_brands_associated_with_highest_spending_mftr.index[2][1]))]

top_3_brands_perct_increase = df_new.loc[(df_new != 0).all(axis=1), :].assign(percentage_increase = ((df_new['Avg_Spnd_Per_Clm_2019'] - df_new['Avg_Spnd_Per_Clm_2018']) / df_new['Avg_Spnd_Per_Clm_2018']) * 100)

top_3_brands_perct_increase
# Out:
#        Brnd_Name        Mftr_Name  Avg_Spnd_Per_Clm_2018  \
# 6965  Humira Pen          Overall            5211.964489
# 6966  Humira Pen    Abbvie US LLC            5211.964489
# 8172      Latuda          Overall            1241.935093
# 8173      Latuda  Sunovion Pharma            1241.935093
# 8957     Mavyret          Overall           11323.304565
# 8958     Mavyret    Abbvie US LLC           11323.304565
#
#       Avg_Spnd_Per_Clm_2019  percentage_increase
# 6965            5883.829444            12.890820
# 6966            5883.829444            12.890820
# 8172            1255.782467             1.114984
# 8173            1255.782467             1.114984
# 8957           12424.829259             9.727944
# 8958           12424.829259             9.727944

# %%
# Question 22: Among the brands from Question 21 that have a positive percenatge increase in average spending per claim, find the brand with the highest total spending in 2019. 

df_new = df_mdata[['Brnd_Name', 'Tot_Spndng_2019']]

top_3_brands_positive = top_3_brands_perct_increase.loc[top_3_brands_perct_increase['percentage_increase'] > 0]

merged_df = pd.merge(df_new, top_3_brands_positive, on='Brnd_Name', how='inner')

merged_df.groupby(['Brnd_Name'])['Tot_Spndng_2019'].sum().nlargest(1)
# Out:
# Brnd_Name
# Latuda    5.384755e+09
# Name: Tot_Spndng_2019, dtype: float64

# %%
# Question 23: Top 3 manufacturers with names starting with 'A' or 'a', based on total spending for Brands in 2018

df_mftr_tot_spend_2018 = df_mdata[['Mftr_Name','Tot_Spndng_2018']]

df_mftr_tot_spend_2018 = df_mftr_tot_spend_2018.loc[df_mftr_tot_spend_2018['Mftr_Name'].str.startswith('A', 'a')]

tot_spend_2018 = df_mftr_tot_spend_2018.groupby(['Mftr_Name'])['Tot_Spndng_2018'].sum()

sorting_of_manufacturer = tot_spend_2018.sort_values(ascending=False).nlargest(3)

sorting_of_manufacturer

#creating a dataframe to generate a table
table = pd.DataFrame({'Manufacturers': sorting_of_manufacturer.index,'Total Spending for Brands 2018':sorting_of_manufacturer.values})
print("Below is the table showing manufacturer names starting with 'A' or 'a', based on total spending for Brands in 2018")
table
# Out:
# Below is the table showing manufacturer names starting with 'A' or 'a', based on total spending for Brands in 2018
#    Manufacturers  Total Spending for Brands 2018
# 0  Abbvie US LLC                    3.441056e+09
# 1          Amgen                    1.846425e+09
# 2    Astrazeneca                    1.364785e+09

# %%
# Question 24: Identify the top 5 generic drugs based on the total number of dosage units in 2019. Plot a histogram in Python

generic_drug = df_mdata.groupby(['Gnrc_Name'])
tot_dosage_unit_2019 = generic_drug['Tot_Dsg_Unts_2019'].sum()
sorting_of_generic_drugs = tot_dosage_unit_2019.sort_values(ascending=False)
top_five_generic_drugs_tot_number_dosage_units_2019 = sorting_of_generic_drugs.head(5)



plt.figure(figsize=(10,6))

plt.bar(top_five_generic_drugs_tot_number_dosage_units_2019.index, top_five_generic_drugs_tot_number_dosage_units_2019.values, color='skyblue', edgecolor='black')
plt.xlabel('Generic Drug')
plt.ylabel('Total Dosage Units 2019')
plt.title('Top 5 generic drugs based on the total number of dosage units in 2019')

plt.show()

# creating a dataframe to generate a table
table = pd.DataFrame({'Generic Drugs':top_five_generic_drugs_tot_number_dosage_units_2019.index, 'Top Total dosage Units 2019':top_five_generic_drugs_tot_number_dosage_units_2019.values})
print("Below is the table showing brand names with highest average spending per claim in the Year 2019")
table
# Out:
# Below is the table showing brand names with highest average spending per claim in the Year 2019
#                     Generic Drugs  Top Total dosage Units 2019
# 0           0.9 % Sodium Chloride                 4.420203e+09
# 1                     Amoxicillin                 2.889964e+09
# 2  PEG3350/Sod Sulf,Bicarb,Cl/KCl                 2.815912e+09
# 3                      Gabapentin                 2.562289e+09
# 4                       Ibuprofen                 2.195557e+09
